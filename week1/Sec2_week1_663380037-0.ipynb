# %% [markdown]
# *Task 1.1*![image.png](attachment:image.png)

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# *Task 1.2*![image.png](attachment:image.png)

# %%
age = int(21)
grade = float(3.19)
fav_color = ("Black & Red & White & Blue")
student = True

print(
type(age),
type(grade),
type(fav_color),
type(student)
)

print("Hi my name is Piyaphat Rattanarak. I am ", age, "years old. \nMy average grade is ", grade,". \nMy favorite color is ",fav_color,".")
print("Student =", student)
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
# Hi my name is Piyaphat Rattanarak. I am  21 years old.
# My average grade is  3.19 .
# My favorite color is  Black & Red & White & Blue .
# Student = True

# %%
num1 = 5
num2 = 9

print("+ :",num1 + num2)
print("- :",num1 - num2)
print("* :",num1 * num2)
print("/ :",num1 / num2)
# Out:
# + : 14
# - : -4
# * : 45
# / : 0.5555555555555556

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
First_name = "Piyaphat"
Last_name = "Rattanarak"
print(f"Hello, {First_name} {Last_name}!")
# Out:
# Hello, Piyaphat Rattanarak!

# %%
user_input = input("Please Enter Your Favorite Number :")
print(user_input)
print(type(user_input))

user_input = int(user_input)
print(user_input)
print(type(user_input))
print("Add 5 =", user_input+5)
# Out:
# 5
# <class 'str'>
# 5
# <class 'int'>
# Add 5 = 10
