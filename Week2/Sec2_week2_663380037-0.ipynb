# %% [markdown]
# *lab2_1.py*
#
# เขียนโปรแกรมที่รับตัวเลขจำนวนเต็มจากผู้ใช้ 1 ค่า แล้วแสดงผลว่าตัวเลขนั้นเป็นบวก ลบ หรือศูนย์ และเป็นเลขคู่หรือคี่ โดยรวมผลลัพธ์ทั้งสองในประโยคเดียว เช่น "The number is negative and odd."

# %%
u_in = int(input("Number Input :"))
print("The input Number is :", u_in)

if u_in > 0 and u_in % 2 == 0:
    print("The number is positive and even")
elif u_in < 0 and u_in % 2 == 0:
    print("The number is negative and even")
elif u_in == 0:
    print("The Number is Zero")
elif u_in > 0 and u_in % 2 == 1:
    print("The number is positive and odd")
elif u_in < 0 and u_in % 2 == 1:
    print("The number is negative and odd")
else:
    print("Error", u_in)
# Out:
# The input Number is : -5
# The number is negative and odd

# %% [markdown]
# *lab2_2.py*
#
# เขียนโปรแกรมที่รับอายุจากผู้ใช้ แล้วแนะนำประเภทภาพยนตร์ที่เหมาะสมตามช่วงอายุ จากนั้นถามเพิ่มเติมว่าชอบภาพยนตร์แอคชันหรือไม่ หากอายุ 18 ปีขึ้นไปและตอบว่า yes ให้แสดงข้อความแนะนำพิเศษ
#
# ปล.1 สามารถดูคำสั่งเพิ่มเติมอย่างละเอียดได้จาก "Detailed Labs" ในไฟล์
#
# ปล.2 การทำ "Challenge" อาจมีส่วนช่วยในการได้รับคะแนนเพิ่มขึ้น

# %%
age_user = int(input("Input your age :"))
print("The input age is :", age_user)

print("Movie : <Horror> Ghost Buster (0+), Teeyod (13+), Incidious (18+). \n <Romantic> Titanic (13+). \n <Action> Bud Light year (0+), Tenet (13+), Reacher (18+).")

movie_type = input("Please answer your prefer movie type. (Action, Romantic, Horror) : ").lower().strip()
print("User Selct Movie type :", movie_type)

if age_user < 13:
    if movie_type == "action":
        print("We would like to recommend you Bud Light year (0+).")
    elif movie_type == "romantic":
        print("no recommend for you! ")
    elif movie_type == "horror":
        print("no recommend for you! ")
    else:
        print("We don't know what you talking about?")

elif age_user >= 13 and age_user < 18:
    if movie_type == "action":
        print("We would like to recommend you Bud Light year (0+), Tenet (13+).")
    elif movie_type == "romantic":
        print("We would like to recommend you Titanic (13+).")
    elif movie_type == "horror":
        print("We would like to recommend you Teeyod (13+).")
    else:
        print("We don't know what you talking about?")
        
elif age_user >= 18:
    if movie_type == "action":
        print("We would like to recommend you Bud Light year (0+), Tenet (13+), Reacher (18+).")
    elif movie_type == "romantic":
        print("We would like to recommend you Titanic (13+).")
    elif movie_type == "horror":
        print("We would like to recommend you Teeyod (13+), Incidious (18+).")
    else:
        print("We don't know what you talking about?")
    
else: 
    print("Error")
# Out:
# The input age is : 10
# Movie : <Horror> Ghost Buster (0+), Teeyod (13+), Incidious (18+)
#  <Romantic> Titanic (13+)
#  <Action> Bud Light year (0+), Tenet (13+), Reacher (18+)
# User Selct Movie type : action
# We would like to recommend you Bud Light year (0+)

# %%
age_user = int(input("Input your age :"))
print("The input age is :", age_user)

movie_type = input("Are you like Action movie? (yes,no) :").lower().strip()
print(movie_type)

if age_user < 13 and movie_type == "yes":
    print("We would like to recommend you Bud Light year")

elif age_user >= 13 and age_user < 18 and movie_type == "yes":
    print("We would like to recommend you Tenet")
   
elif age_user >= 18 and movie_type == "yes":
    print("We would like to recommend you Reacher")
    
else: 
   print("Sad T-T. You not like Action movie.")
# Out:
# The input age is : 70
# yes
# We would like to recommend you Reacher

# %% [markdown]
# *Activity 2.1*
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# If จะเริ่มก่อนโดยความหมายคือ "ถ้า",
#
# elif จะมาหลังจากประกาศ if ไปแล้ว มีความหมายเหมือน "แล้วถ้า",
#
# else คือ อื่นๆ นอเหนือจากเงื่อนไขที่กำหนดให้
#
# And คือ "และ" จะใช้ก็ต่อเมื่อเรามีเงื่อนไขที่เจาะจงเพิ่มอีกข้อ เช่น ถ้า  1=1 And 2=2 แปลว่า 3=3 .
#
# Or คือ "หรือ" จะใช้ตอนเงื่อนไขที่อาจจะต้องการคำตอบเดียวกัน แต่มีมากกว่า1 input เช่น 1=1 or one=1 แปลว่า 1=one .
#
# Not คือ "ยกเว้น" จะใช้ตอนเงื่อนไขที่ไม่ต้องการบางสิ่งบางอย่างใน input เช่น user_input not 10  แปลว่า จะเข้าเงื่อนไขทุกเลข ยกเว้นเลข10

# %% [markdown]
# *Activity 2.2*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ส่วนใหญ่ออกแบบได้เป็นเกมแนวทางเลือก ที่ผู้เล่นต้องเลือกเส้นทางเอง
# โดยผมออกแบบเป็นเกม เนื้อเรื่องแนวไซไฟ นอกโลก
#
# ผู้เล่นจะได้เลือกโลกหรือดาวที่ผู้เล่นจะเกิดโดยใช้ Input()
#
# จากนั้น If ผู้เล่นเลือก โลก ผู้เล่นจะต้อง เรียน ทำงาน หาเงิน และซื้อจรวดเพื่อสำรวจนอกโลก
#
# elif ผู้เล่นเลือก ดวงจันทร์ ผู้เล่นจะต้องสร้างฟาร์ม สาธารณูปโภค และฐานทัพ เพื่อป้องกันเอเลี่ยนมาบก
#
# else ผู้เล่นอยู่ Galaxy อื่น ผู้เล่นกลายเป็นเอเลี่ยน แล้วต้องหาวิธีบุกโลก
